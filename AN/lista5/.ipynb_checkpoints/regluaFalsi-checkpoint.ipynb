# %% [markdown]
# # regula Falsi
#
# ## Idea:
#  - bierzemy punkty początkowe a i b, gdzie $/aplha$ należy do (a, b) oraz f(a)f(b) < 0
#  - rysujemy prostą z punktu (a, f(a)) do (b, f(b))
#  - znajdujemy miejsce zerowe prostej - x0
#  - jeżeli funkcja jest tego samego znaku w punktach x0 i a, ustawiamy a jako x0, i odwrotnie
#
# ## Zalety:
#  - jeżeli funkcja jest liniowa, otrzymujemy $/alpha$ w jednym kroku
#  - nie potrzeba pochodnej

# %%
using Plots

f(x) = sign(x)

a = -3
b = 2.5

plt = plot(
    1,
    xlim = (-3, 3),
    legend = false,
    marker = 2,
)

plot!(plt, f)
plot!(plt, [a, b], [f(a), f(b)]) 
plot!(plt, [a, a], [0, f(a)], linestyle = :dash) 
plot!(plt, [b, b], [0, f(b)], linestyle = :dash) 
scatter!(plt, [a, a, b, b],[0, f(a), 0, f(b)])
itr = 1
while (itr < 7)
    itr = itr + 1

    x = a - f(a) * (a-b) / (f(a)-f(b))
    if f(x)*f(a) > 0
        a = x
        plot!(plt, [a, a], [0, f(a)], linestyle = :dash) 
    else
        b = x
        plot!(plt, [b, b], [0, f(b)], linestyle = :dash) 
    end
    println(x)
    plot!(plt, [a, b], [f(a), f(b)]) 
    scatter!(plt, [a, a, b, b],[0, f(a), 0, f(b)])
    # scatter!(plt, [x],[0])
end
display(plt)
savefig(plt, "exmpl2.svg")
# Out:
# -0.25
# 1.125
# 0.4375
# 0.09375
# -0.078125
# 0.0078125
# "C:\\Users\\rafal\\Desktop\\UWr\\AN\\lista5\\exmpl2.svg"

# %%
using Plots

f(x) = (x/2)^2 - sin(x)

a = 0.9
b = 2.4

plt = plot(
    1,
    xlim = (0.8, 2.5),
    legend = false,
    marker = 2,
)

plot!(plt, f)
plot!(plt, [a, b], [f(a), f(b)]) 
plot!(plt, [a, a], [0, f(a)], linestyle = :dash) 
plot!(plt, [b, b], [0, f(b)], linestyle = :dash) 
scatter!(plt, [a, a, b, b],[0, f(a), 0, f(b)])
itr = 1
while (itr < 5)
    itr = itr + 1

    x = a - f(a) * (a-b) / (f(a)-f(b))
    if f(x)*f(a) > 0
        a = x
        plot!(plt, [a, a], [0, f(a)], linestyle = :dash) 
    else
        b = x
        plot!(plt, [b, b], [0, f(b)], linestyle = :dash) 
    end
    println(x)
    plot!(plt, [a, b], [f(a), f(b)]) 
    scatter!(plt, [a, a, b, b],[0, f(a), 0, f(b)])
    # scatter!(plt, [x],[0])
end
display(plt)
savefig(plt, "exmpl1.svg")
# Out:
# 1.5475872253813328
# 1.8408452754642635
# 1.914826681504717
# 1.930047989665695
# "C:\\Users\\rafal\\Desktop\\UWr\\AN\\lista5\\exmpl1.svg"

# %%
using Plots

f(x) = 5x -3

a = 0.9
b = 2.4

plt = plot(
    1,
    xlim = (0, 3),
    legend = false,
    marker = 2,
)

plot!(plt, f)
plot!(plt, [a, b], [f(a), f(b)]) 
plot!(plt, [a, a], [0, f(a)], linestyle = :dash) 
plot!(plt, [b, b], [0, f(b)], linestyle = :dash) 
scatter!(plt, [a, a, b, b],[0, f(a), 0, f(b)])
itr = 1
while (itr < 5)
    itr = itr + 1

    x = a - f(a) * (a-b) / (f(a)-f(b))
    if f(x)*f(a) > 0
        a = x
        plot!(plt, [a, a], [0, f(a)], linestyle = :dash) 
    else
        b = x
        plot!(plt, [b, b], [0, f(b)], linestyle = :dash) 
    end
    println(x)
    plot!(plt, [a, b], [f(a), f(b)]) 
    scatter!(plt, [a, a, b, b],[0, f(a), 0, f(b)])
    # scatter!(plt, [x],[0])
end
display(plt)
savefig(plt, "exmpl2.svg")
# Out:
# 0.6000000000000001
# 0.6
# 0.6
# 0.6
# "C:\\Users\\rafal\\Desktop\\UWr\\AN\\lista5\\exmpl2.svg"
